# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2, 3, tight_layout=True)

#折れ線グラフ
y0 = [1, 2, -5, 2]
axes[0,0].plot(y0)

#sin関数
x = np.linspace(0, 10, 100)
y = 2 + 2 * np.sin(2 * x)
axes[0,1].plot(y)

#ヒストグラム
z = np.random .normal(15, 5, 2000)
axes[0,2].hist(z)

#散布図
x1 = 4 + np.random.normal(0, 2, 60)
y1 = 4 + np.random.normal(0, 2, len(x1))
axes[1,0].scatter(x1, y1)

plt.show()
